# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.barplot(x=['A','B','C'],y=[1,3,2])
plt.show()

# %%
sns.set(style='dark',palette='dark',font="Times new Roman",font_scale = 1)
sns.barplot(x=['A','B','C'],y=[1,3,2])
plt.show()
